# %% [markdown]
# # Soldier Pipeline Testing
#
# Simple notebook to test the alignment pipeline. Uses:
# - **Jina** for embeddings and reranking
# - **OpenRouter** (Cerebras/Groq) for fast LLM calls
#
# All setup is handled by `bootstrap()` - just run the cells!

# %%
# Setup
import asyncio
import nest_asyncio
from dotenv import load_dotenv

load_dotenv()
nest_asyncio.apply()

def run(coro):
    return asyncio.get_event_loop().run_until_complete(coro)

print("Setup complete!")
# Out:
# Setup complete!

# %%
# Bootstrap engine and stores
from soldier.bootstrap import bootstrap, create_sample_rule, create_sample_scenario

engine, ctx = bootstrap(log_level="INFO")

print(f"Tenant: {ctx.tenant_id}")
print(f"Agent: {ctx.agent_id}")
print(f"Session: {ctx.session_id}")
# Out:
# {"event": "jina_providers_created", "level": "info", "timestamp": "[PHONE]T02:00:06.730530Z"}
# {"tenant_id": "79f522b8-dd35-4685-bf37-6aa9f387f314", "agent_id": "53bf3f[PHONE]e-b38f-2316c4557686", "model": "openrouter/openai/gpt-oss-120b", "provider_order": ["Cerebras", "Groq", "SambaNova"], "event": "engine_bootstrapped", "level": "info", "timestamp": "[PHONE]T02:00:06.759657Z"}
# {"session_id": "0be0b7af-d362-4b5e-97f4-98d5e1e19dee", "event": "session_created", "level": "info", "timestamp": "[PHONE]T02:00:06.761077Z"}
# Tenant: 79f522b8-dd35-4685-bf37-6aa9f387f314
# Agent: 53bf3f72-9974-438e-b38f-2316c4557686
# Session: 0be0b7af-d362-4b5e-97f4-98d5e1e19dee

# %% [markdown]
# ## Create Rules
#
# Rules define agent behavior. Each has condition + action.

# %%
# Create sample rules
async def setup_rules():
    await create_sample_rule(
        ctx,
        name="Greeting Rule",
        condition_text="User sends a greeting or says hello",
        action_text="Respond with a friendly greeting and ask how you can help",
        priority=80,
    )
    
    await create_sample_rule(
        ctx,
        name="Order Status Rule",
        condition_text="User asks about their order status or tracking",
        action_text="Ask for order number if not provided, then look up status",
        priority=90,
    )
    
    await create_sample_rule(
        ctx,
        name="Professional Language",
        condition_text="Any customer interaction",
        action_text="Always use professional, helpful language",
        priority=100,
        is_hard_constraint=True,
    )
    
    await create_sample_rule(
        ctx,
        name="Refund Request Rule",
        condition_text="User asks for a refund or wants money back",
        action_text="Express understanding, ask for order number, explain refund policy",
        priority=85,
    )

run(setup_rules())
print("Rules created!")
# Out:
# {"model": "jina-embeddings-v3", "task": "retrieval.query", "dimensions": 1024, "num_texts": 1, "event": "jina_embed_request", "level": "debug", "timestamp": "[PHONE]T02:00:06.783240Z"}
# {"model": "jina-embeddings-v3", "num_embeddings": 1, "dimensions": 1024, "event": "jina_embed_success", "level": "debug", "timestamp": "[PHONE]T02:00:07.906569Z"}
# {"name": "Greeting Rule", "has_embedding": true, "event": "rule_created", "level": "info", "timestamp": "[PHONE]T02:00:07.907373Z"}
# {"model": "jina-embeddings-v3", "task": "retrieval.query", "dimensions": 1024, "num_texts": 1, "event": "jina_embed_request", "level": "debug", "timestamp": "[PHONE]T02:00:07.908004Z"}
# {"model": "jina-embeddings-v3", "num_embeddings": 1, "dimensions": 1024, "event": "jina_embed_success", "level": "debug", "timestamp": "[PHONE]T02:00:08.543205Z"}
# {"name": "Order Status Rule", "has_embedding": true, "event": "rule_created", "level": "info", "timestamp": "[PHONE]T02:00:08.544906Z"}
# {"model": "jina-embeddings-v3", "task": "retrieval.query", "dimensions": 1024, "num_texts": 1, "event": "jina_embed_request", "level": "debug", "timestamp": "[PHONE]T02:00:08.545961Z"}
# {"model": "jina-embeddings-v3", "num_embeddings": 1, "dimensions": 1024, "event": "jina_embed_success", "level": "debug", "timestamp": "[PHONE]T02:00:09.004135Z"}
# {"name": "Professional Language", "has_embedding": true, "event": "rule_created", "level": "info", "timestamp": "[PHONE]T02:00:09.004988Z"}
# {"model": "jina-embeddings-v3", "task": "retrieval.query", "dimensions": 1024, "num_texts": 1, "event": "jina_embed_request", "level": "debug", "timestamp": "[PHONE]T02:00:09.006467Z"}
# {"model": "jina-embeddings-v3", "num_embeddings": 1, "dimensions": 1024, "event": "jina_embed_success", "level": "debug", "timestamp": "[PHONE]T02:00:09.487558Z"}
# {"name": "Refund Request Rule", "has_embedding": true, "event": "rule_created", "level": "info", "timestamp": "[PHONE]T02:00:09.489833Z"}
# Rules created!

# %%
# Create sample scenario
run(create_sample_scenario(
    ctx,
    name="Order Support Flow",
    description="Handle customer order inquiries",
    entry_condition_text="User asks about an order",
    step_instructions="Ask for order number and provide status",
))
print("Scenario created!")
# Out:
# {"model": "jina-embeddings-v3", "task": "retrieval.query", "dimensions": 1024, "num_texts": 1, "event": "jina_embed_request", "level": "debug", "timestamp": "[PHONE]T02:00:09.514176Z"}
# {"model": "jina-embeddings-v3", "num_embeddings": 1, "dimensions": 1024, "event": "jina_embed_success", "level": "debug", "timestamp": "[PHONE]T02:00:09.976082Z"}
# {"name": "Order Support Flow", "has_embedding": true, "event": "scenario_created", "level": "info", "timestamp": "[PHONE]T02:00:09.976801Z"}
# Scenario created!

# %% [markdown]
# ## Helper Function

# %%
def display_result(result, message):
    """Pretty print pipeline result."""
    print("=" * 70)
    print(f"MESSAGE: {message}")
    print("=" * 70)
    print(f"\nRESPONSE:\n{result.response}")
    print(f"\n{'=' * 70}")
    print("PIPELINE LATENCIES:")
    print("=" * 70)
    for timing in result.pipeline_timings:
        status = "SKIPPED" if timing.skipped else f"{timing.duration_ms:.2f}ms"
        print(f"  {timing.step:25} {status}")
    print(f"  {'─' * 40}")
    print(f"  {'TOTAL':25} {result.total_time_ms:.2f}ms")
    print(f"\nMatched Rules: {len(result.matched_rules)}")
    for mr in result.matched_rules:
        score = getattr(mr, 'relevance_score', getattr(mr, 'match_score', 0.0))
        print(f"  - {mr.rule.name} (score: {score:.2f})")
    if result.situational_snapshot:
        print(f"\nSituational Snapshot:")
        print(f"  Language: {result.situational_snapshot.language}")
        print(f"  Sentiment: {result.situational_snapshot.sentiment}")
        print(f"  Topic: {result.situational_snapshot.topic}")
    print()

# %% [markdown]
# ## Test Messages

# %%
# Test 1: Greeting
message = "Hello! I need some help today."

result = run(engine.process_turn(
    message=message,
    session_id=ctx.session_id,
    tenant_id=ctx.tenant_id,
    agent_id=ctx.agent_id,
))

display_result(result, message)
# Out:
# {"session_id": "0be0b7af-d362-4b5e-97f4-98d5e1e19dee", "tenant_id": "79f522b8-dd35-4685-bf37-6aa9f387f314", "agent_id": "53bf3f[PHONE]e-b38f-2316c4557686", "message_length": 30, "event": "processing_turn", "level": "info", "timestamp": "[PHONE]T02:00:09.999147Z"}
# {"tenant_id": "79f522b8-dd35-4685-bf37-6aa9f387f314", "customer_id": "a255b789-4fdb-4af0-a88b-996b97b86521", "channel": "api", "event": "customer_created", "level": "info", "timestamp": "[PHONE]T02:00:09.999967Z"}
# {"tenant_id": "79f522b8-dd35-4685-bf37-6aa9f387f314", "agent_id": "53bf3f[PHONE]e-b38f-2316c4557686", "item_count": 0, "event": "glossary_loaded", "level": "info", "timestamp": "[PHONE]T02:00:10.000568Z"}
# {"tenant_id": "79f522b8-dd35-4685-bf37-6aa9f387f314", "agent_id": "53bf3f[PHONE]e-b38f-2316c4557686", "field_count": 0, "event": "customer_data_schema_loaded", "level": "info", "timestamp": "[PHONE]T02:00:10.001155Z"}
# {"customer_id": "a255b789-4fdb-4af0-a88b-996b97b86521", "tenant_id": "79f522b8-dd35-4685-bf37-6aa9f387f314", "field_count": 0, "event": "customer_data_loaded", "level": "info", "timestamp": "[PHONE]T02:00:10.001835Z"}
# {"tenant_id": "79f522b8-dd35-4685-bf37-6aa9f387f314", "agent_id": "53bf3f[PHONE]e-b38f-2316c4557686", "session_id": "0be0b7af-d362-4b5e-97f4-98d5e1e19dee", "customer_id": "a255b789-4fdb-4af0-a88b-996b97b86521", "turn_number": 1, "is_new_customer": true, "has_reconciliation": false, "event": "turn_context_built", "level": "info", "timestamp": "[PHONE]T02:00:10.002653Z"}
# {"customer_id": "a255b789-4fdb-4af0-a88b-996b97b86521", "tenant_id": "79f522b8-dd35-4685-bf37-6aa9f387f314", "field_count": 0, "event": "customer_data_loaded", "level": "info", "timestamp": "[PHONE]T02:00:10.003580Z"}
# {"tenant_id": "79f522b8-dd35-4685-bf37-6aa9f387f314", "agent_id": "53bf3f[PHONE]e-b38f-2316c4557686", "item_count": 0, "event": "glossary_loaded", "level": "info", "timestamp": "[PHONE]T02:00:10.004243Z"}
# {"tenant_id": "79f522b8-dd35-4685-bf37-6aa9f387f314", "agent_id": "53bf3f[PHONE]e-b38f-2316c4557686", "field_count": 0, "event": "customer_data_schema_loaded", "level": "info", "timestamp": "[PHONE]T02:00:10.004877Z"}
# {"model": "openrouter/openai/gpt-oss-120b", "step": "situational_sensor", "provider_order": ["Cerebras", "Groq", "SambaNova"], "provider_sort": "latency", "event": "openrouter_provider_config_applied", "level": "debug", "timestamp": "[PHONE]T02:00:10.012932Z"}
# {"model": "openrouter/openai/gpt-oss-120b", "step": "situational_sensor", "latency_ms": 3133.16, "content_length": 417, "backend_provider": "OpenRouter", "event": "executor_generate_complete", "level": "debug", "timestamp": "[PHONE]T02:00:13.147092Z"}
# {"model": "jina-embeddings-v3", "task": "retrieval.passage", "dimensions": 1024, "num_texts": 1, "event": "jina_embed_request", "level": "debug", "timestamp": "[PHONE]T02:00:13.148435Z"}
# {"model": "jina-embeddings-v3", "task": "retrieval.passage", "dimensions": 1024, "num_texts": 1, "event": "jina_embed_request", "level": "debug", "timestamp": "[PHONE]T02:00:13.150605Z"}
# {"tenant_id": "79f522b8-dd35-4685-bf37-6aa9f387f314", "agent_id": "53bf3f[PHONE]e-b38f-2316c4557686", "event": "no_intents_configured", "level": "debug", "timestamp": "[PHONE]T02:00:13.152264Z"}
# {"model": "jina-embeddings-v3", "num_embeddings": 1, "dimensions": 1024, "event": "jina_embed_success", "level": "debug", "timestamp": "[PHONE]T02:00:13.814370Z"}
# {"model": "jina-embeddings-v3", "num_embeddings": 1, "dimensions": 1024, "event": "jina_embed_success", "level": "debug", "timestamp": "[PHONE]T02:00:14.119285Z"}
# {"total_candidates": 4, "selected": 1, "elapsed_ms": 973.4913827851415, "event": "rules_retrieved", "level": "debug", "timestamp": "[PHONE]T02:00:14.121957Z"}
# {"intent": "request_help", "confidence": 0.0, "hybrid_candidates_count": 0, "reason": "no_confident_match", "event": "using_sensor_intent_fallback", "level": "debug", "timestamp": "[PHONE]T02:00:14.124224Z"}
# {"count": 1, "elapsed_ms": 977.8557042591274, "event": "rules_retrieved", "level": "debug", "timestamp": "[PHONE]T02:00:14.126284Z"}
# {"num_candidates": 1, "batch_size": 5, "event": "filtering_rules", "level": "debug", "timestamp": "[PHONE]T02:00:14.127793Z"}
# {"model": "openrouter/openai/gpt-oss-120b", "step": "rule_filtering", "provider_order": ["Cerebras", "Groq", "SambaNova"], "provider_sort": "latency", "event": "openrouter_provider_config_applied", "level": "debug", "timestamp": "[PHONE]T02:00:14.129231Z"}
# {"model": "openrouter/openai/gpt-oss-120b", "step": "rule_filtering", "latency_ms": 1287.79, "content_length": 391, "backend_provider": "OpenRouter", "event": "executor_generate_complete", "level": "debug", "timestamp": "[PHONE]T02:00:15.418457Z"}
# {"matched": 1, "rejected": 0, "unsure": 0, "unsure_policy": "exclude", "elapsed_ms": 1291.5259771980345, "event": "rules_filtered", "level": "info", "timestamp": "[PHONE]T02:00:15.419334Z"}
# {"session_id": "0be0b7af-d362-4b5e-97f4-98d5e1e19dee", "scenario_id": "[PHONE]b6-4175-94ef-c6e95a1d7b3c", "step_id": "14d3e6a5-7d8a-4038-97cc-b4fd42b845b3", "action": "start", "event": "checking_scenario_requirements", "level": "info", "timestamp": "[PHONE]T02:00:15.422139Z"}
# {"event": "fill_scenario_requirements_missing_customer_id", "level": "warning", "timestamp": "[PHONE]T02:00:15.424542Z"}
# {"session_id": "0be0b7af-d362-4b5e-97f4-98d5e1e19dee", "scenario_id": "[PHONE]b6-4175-94ef-c6e95a1d7b3c", "event": "scenario_requirements_satisfied", "level": "info", "timestamp": "[PHONE]T02:00:15.426874Z"}
# {"response_type": "ANSWER", "num_rules": 1, "num_contributions": 0, "event": "response_type_determined", "level": "info", "timestamp": "[PHONE]T02:00:15.428180Z"}
# {"response_type": "ANSWER", "num_templates": 0, "num_contributions": 0, "num_must_include": 0, "num_must_avoid": 0, "num_constraints": 0, "event": "response_plan_built", "level": "info", "timestamp": "[PHONE]T02:00:15.429223Z"}
# {"model": "openrouter/openai/gpt-oss-120b", "step": "generation", "provider_order": ["Cerebras", "Groq", "SambaNova"], "provider_sort": "latency", "event": "openrouter_provider_config_applied", "level": "debug", "timestamp": "[PHONE]T02:00:15.430390Z"}
# {"model": "openrouter/openai/gpt-oss-120b", "step": "generation", "latency_ms": 1399.2, "content_length": 32, "backend_provider": "OpenRouter", "event": "executor_generate_complete", "level": "debug", "timestamp": "[PHONE]T02:00:16.830745Z"}
# {"error": "Expecting value: line 1 column 1 (char 0)", "event": "llm_output_not_json", "level": "debug", "timestamp": "[PHONE]T02:00:16.831716Z"}
# {"response_length": 32, "elapsed_ms": 1401.9941040314734, "model": "openrouter/openai/gpt-oss-120b", "response_type": "ANSWER", "categories": 1, "channel": "web", "event": "response_generated", "level": "debug", "timestamp": "[PHONE]T02:00:16.832288Z"}
# {"session_id": "0be0b7af-d362-4b5e-97f4-98d5e1e19dee", "operations": 1, "duration_ms": 0.7313936948776245, "failures": 0, "event": "parallel_persistence_complete", "level": "info", "timestamp": "[PHONE]T02:00:16.835088Z"}
# {"session_id": "0be0b7af-d362-4b5e-97f4-98d5e1e19dee", "turn_id": "dc59bc31-0cb1-46de-8762-cd2b5103f10f", "total_time_ms": 6835.16251295805, "matched_rules": 1, "response_length": 32, "event": "turn_processed", "level": "info", "timestamp": "[PHONE]T02:00:16.837627Z"}
# ======================================================================
# MESSAGE: Hello! I need some help today.
# ======================================================================
#
# RESPONSE:
# Hello! How can I help you today?
#
# ======================================================================
# PIPELINE LATENCIES:
# ======================================================================
#   customer_resolution       0.64ms
#   reconciliation            SKIPPED
#   situational_sensor        3144.69ms
#   retrieval                 977.86ms
#   rule_filtering            1293.87ms
#   scenario_filtering        0.14ms
#   requirement_check         4.61ms
#   tool_execution            SKIPPED
#   response_planning         2.20ms
#   generation                1403.77ms
#   enforcement               SKIPPED
#   ────────────────────────────────────────
#   TOTAL                     6835.16ms
#
# Matched Rules: 1
#   - Greeting Rule (score: 1.00)
#
# Situational Snapshot:
#   Language: en
#   Sentiment: Sentiment.NEUTRAL
#   Topic: help

# %%
# Test 2: Order inquiry
message = "Where is my order? I ordered something last week."

result = run(engine.process_turn(
    message=message,
    session_id=ctx.session_id,
    tenant_id=ctx.tenant_id,
    agent_id=ctx.agent_id,
))

display_result(result, message)
# Out:
# {"session_id": "0be0b7af-d362-4b5e-97f4-98d5e1e19dee", "tenant_id": "79f522b8-dd35-4685-bf37-6aa9f387f314", "agent_id": "53bf3f[PHONE]e-b38f-2316c4557686", "message_length": 49, "event": "processing_turn", "level": "info", "timestamp": "[PHONE]T02:00:16.862919Z"}
# {"tenant_id": "79f522b8-dd35-4685-bf37-6aa9f387f314", "customer_id": "a255b789-4fdb-4af0-a88b-996b97b86521", "channel": "api", "event": "customer_resolved", "level": "info", "timestamp": "[PHONE]T02:00:16.865608Z"}
# {"session_id": "0be0b7af-d362-4b5e-97f4-98d5e1e19dee", "pending_migration": false, "version_mismatch": true, "event": "executing_reconciliation", "level": "info", "timestamp": "[PHONE]T02:00:16.867062Z"}
# {"session_id": "0be0b7af-d362-4b5e-97f4-98d5e1e19dee", "session_version": null, "current_version": 1, "event": "version_mismatch_detected", "level": "info", "timestamp": "[PHONE]T02:00:16.868088Z"}
# {"session_id": "0be0b7af-d362-4b5e-97f4-98d5e1e19dee", "scenario_id": "[PHONE]b6-4175-94ef-c6e95a1d7b3c", "event": "fallback_reconciliation", "level": "info", "timestamp": "[PHONE]T02:00:16.869717Z"}
# {"session_id": "0be0b7af-d362-4b5e-97f4-98d5e1e19dee", "entry_step": "14d3e6a5-7d8a-4038-97cc-b4fd42b845b3", "event": "fallback_relocalize_to_entry", "level": "info", "timestamp": "[PHONE]T02:00:16.870745Z"}
# {"session_id": "0be0b7af-d362-4b5e-97f4-98d5e1e19dee", "action": "teleport", "elapsed_ms": 5.097436718642712, "event": "reconciliation_complete", "level": "info", "timestamp": "[PHONE]T02:00:16.872139Z"}
# {"tenant_id": "79f522b8-dd35-4685-bf37-6aa9f387f314", "agent_id": "53bf3f[PHONE]e-b38f-2316c4557686", "item_count": 0, "event": "glossary_loaded", "level": "info", "timestamp": "[PHONE]T02:00:16.873448Z"}
# {"tenant_id": "79f522b8-dd35-4685-bf37-6aa9f387f314", "agent_id": "53bf3f[PHONE]e-b38f-2316c4557686", "field_count": 0, "event": "customer_data_schema_loaded", "level": "info", "timestamp": "[PHONE]T02:00:16.875851Z"}
# {"customer_id": "a255b789-4fdb-4af0-a88b-996b97b86521", "tenant_id": "79f522b8-dd35-4685-bf37-6aa9f387f314", "field_count": 0, "event": "customer_data_loaded", "level": "info", "timestamp": "[PHONE]T02:00:16.876376Z"}
# {"tenant_id": "79f522b8-dd35-4685-bf37-6aa9f387f314", "agent_id": "53bf3f[PHONE]e-b38f-2316c4557686", "session_id": "0be0b7af-d362-4b5e-97f4-98d5e1e19dee", "customer_id": "a255b789-4fdb-4af0-a88b-996b97b86521", "turn_number": 2, "is_new_customer": false, "has_reconciliation": true, "event": "turn_context_built", "level": "info", "timestamp": "[PHONE]T02:00:16.877295Z"}
# {"customer_id": "a255b789-4fdb-4af0-a88b-996b97b86521", "tenant_id": "79f522b8-dd35-4685-bf37-6aa9f387f314", "field_count": 0, "event": "customer_data_loaded", "level": "info", "timestamp": "[PHONE]T02:00:16.878332Z"}
# {"tenant_id": "79f522b8-dd35-4685-bf37-6aa9f387f314", "agent_id": "53bf3f[PHONE]e-b38f-2316c4557686", "item_count": 0, "event": "glossary_loaded", "level": "info", "timestamp": "[PHONE]T02:00:16.879257Z"}
# {"tenant_id": "79f522b8-dd35-4685-bf37-6aa9f387f314", "agent_id": "53bf3f[PHONE]e-b38f-2316c4557686", "field_count": 0, "event": "customer_data_schema_loaded", "level": "info", "timestamp": "[PHONE]T02:00:16.880490Z"}
# {"model": "openrouter/openai/gpt-oss-120b", "step": "situational_sensor", "latency_ms": 5607.49, "content_length": 553, "backend_provider": "OpenRouter", "event": "executor_generate_complete", "level": "debug", "timestamp": "[PHONE]T02:00:22.489868Z"}
# {"model": "jina-embeddings-v3", "task": "retrieval.passage", "dimensions": 1024, "num_texts": 1, "event": "jina_embed_request", "level": "debug", "timestamp": "[PHONE]T02:00:22.492386Z"}
# {"model": "jina-embeddings-v3", "task": "retrieval.passage", "dimensions": 1024, "num_texts": 1, "event": "jina_embed_request", "level": "debug", "timestamp": "[PHONE]T02:00:22.494514Z"}
# {"tenant_id": "79f522b8-dd35-4685-bf37-6aa9f387f314", "agent_id": "53bf3f[PHONE]e-b38f-2316c4557686", "event": "no_intents_configured", "level": "debug", "timestamp": "[PHONE]T02:00:22.497842Z"}
# {"model": "jina-embeddings-v3", "num_embeddings": 1, "dimensions": 1024, "event": "jina_embed_success", "level": "debug", "timestamp": "[PHONE]T02:00:23.124573Z"}
# {"model": "jina-embeddings-v3", "num_embeddings": 1, "dimensions": 1024, "event": "jina_embed_success", "level": "debug", "timestamp": "[PHONE]T02:00:23.324549Z"}
# {"total_candidates": 4, "selected": 1, "elapsed_ms": 834.4171280041337, "event": "rules_retrieved", "level": "debug", "timestamp": "[PHONE]T02:00:23.326845Z"}
# {"intent": "order_status", "confidence": 0.0, "hybrid_candidates_count": 0, "reason": "no_confident_match", "event": "using_sensor_intent_fallback", "level": "debug", "timestamp": "[PHONE]T02:00:23.327797Z"}
# {"count": 1, "elapsed_ms": 840.5735180713236, "event": "rules_retrieved", "level": "debug", "timestamp": "[PHONE]T02:00:23.332987Z"}
# {"num_candidates": 1, "batch_size": 5, "event": "filtering_rules", "level": "debug", "timestamp": "[PHONE]T02:00:23.335655Z"}
# {"model": "openrouter/openai/gpt-oss-120b", "step": "rule_filtering", "latency_ms": 1401.17, "content_length": 427, "backend_provider": "OpenRouter", "event": "executor_generate_complete", "level": "debug", "timestamp": "[PHONE]T02:00:24.739886Z"}
# {"matched": 0, "rejected": 1, "unsure": 0, "unsure_policy": "exclude", "elapsed_ms": 1405.5848103016615, "event": "rules_filtered", "level": "info", "timestamp": "[PHONE]T02:00:24.741187Z"}
# {"response_type": "ANSWER", "num_rules": 0, "num_contributions": 0, "event": "response_type_determined", "level": "info", "timestamp": "[PHONE]T02:00:24.742126Z"}
# {"response_type": "ANSWER", "num_templates": 0, "num_contributions": 0, "num_must_include": 0, "num_must_avoid": 0, "num_constraints": 0, "event": "response_plan_built", "level": "info", "timestamp": "[PHONE]T02:00:24.743121Z"}
# {"model": "openrouter/openai/gpt-oss-120b", "step": "generation", "latency_ms": 1431.39, "content_length": 194, "backend_provider": "OpenRouter", "event": "executor_generate_complete", "level": "debug", "timestamp": "[PHONE]T02:00:26.175886Z"}
# {"error": "Expecting value: line 1 column 1 (char 0)", "event": "llm_output_not_json", "level": "debug", "timestamp": "[PHONE]T02:00:26.176901Z"}
# {"response_length": 194, "elapsed_ms": 1433.9382080361247, "model": "openrouter/openai/gpt-oss-120b", "response_type": "ANSWER", "categories": 1, "channel": "web", "event": "response_generated", "level": "debug", "timestamp": "[PHONE]T02:00:26.178337Z"}
# {"session_id": "0be0b7af-d362-4b5e-97f4-98d5e1e19dee", "operations": 1, "duration_ms": 0.7228860631585121, "failures": 0, "event": "parallel_persistence_complete", "level": "info", "timestamp": "[PHONE]T02:00:26.180411Z"}
# {"session_id": "0be0b7af-d362-4b5e-97f4-98d5e1e19dee", "turn_id": "d4d39c54-c960-4498-a74f-9a9149654e44", "total_time_ms": 9316.804310772568, "matched_rules": 0, "response_length": 194, "event": "turn_processed", "level": "info", "timestamp": "[PHONE]T02:00:26.182604Z"}
# ======================================================================
# MESSAGE: Where is my order? I ordered something last week.
# ======================================================================
#
# RESPONSE:
# I’m happy to help track your order. Could you please share your order number or the email address you used when placing the order? Once I have that information, I can look up the status for you.
#
# ======================================================================
# PIPELINE LATENCIES:
# ======================================================================
#   customer_resolution       1.34ms
#   reconciliation            5.10ms
#   situational_sensor        5613.76ms
#   retrieval                 840.57ms
#   rule_filtering            1406.38ms
#   scenario_filtering        0.03ms
#   requirement_check         SKIPPED
#   tool_execution            SKIPPED
#   response_planning         2.26ms
#   generation                1434.84ms
#   enforcement               SKIPPED
#   ────────────────────────────────────────
#   TOTAL                     9316.80ms
#
# Matched Rules: 0
#
# Situational Snapshot:
#   Language: en
#   Sentiment: Sentiment.NEUTRAL
#   Topic: order_status

# %%
# Test 3: Refund request
message = "I want a refund. The product arrived damaged."

result = run(engine.process_turn(
    message=message,
    session_id=ctx.session_id,
    tenant_id=ctx.tenant_id,
    agent_id=ctx.agent_id,
))

display_result(result, message)
# Out:
# {"session_id": "0be0b7af-d362-4b5e-97f4-98d5e1e19dee", "tenant_id": "79f522b8-dd35-4685-bf37-6aa9f387f314", "agent_id": "53bf3f[PHONE]e-b38f-2316c4557686", "message_length": 45, "event": "processing_turn", "level": "info", "timestamp": "[PHONE]T02:00:26.201880Z"}
# {"tenant_id": "79f522b8-dd35-4685-bf37-6aa9f387f314", "customer_id": "a255b789-4fdb-4af0-a88b-996b97b86521", "channel": "api", "event": "customer_resolved", "level": "info", "timestamp": "[PHONE]T02:00:26.202963Z"}
# {"tenant_id": "79f522b8-dd35-4685-bf37-6aa9f387f314", "agent_id": "53bf3f[PHONE]e-b38f-2316c4557686", "item_count": 0, "event": "glossary_loaded", "level": "info", "timestamp": "[PHONE]T02:00:26.203573Z"}
# {"tenant_id": "79f522b8-dd35-4685-bf37-6aa9f387f314", "agent_id": "53bf3f[PHONE]e-b38f-2316c4557686", "field_count": 0, "event": "customer_data_schema_loaded", "level": "info", "timestamp": "[PHONE]T02:00:26.204054Z"}
# {"customer_id": "a255b789-4fdb-4af0-a88b-996b97b86521", "tenant_id": "79f522b8-dd35-4685-bf37-6aa9f387f314", "field_count": 0, "event": "customer_data_loaded", "level": "info", "timestamp": "[PHONE]T02:00:26.204602Z"}
# {"tenant_id": "79f522b8-dd35-4685-bf37-6aa9f387f314", "agent_id": "53bf3f[PHONE]e-b38f-2316c4557686", "session_id": "0be0b7af-d362-4b5e-97f4-98d5e1e19dee", "customer_id": "a255b789-4fdb-4af0-a88b-996b97b86521", "turn_number": 3, "is_new_customer": false, "has_reconciliation": false, "event": "turn_context_built", "level": "info", "timestamp": "[PHONE]T02:00:26.205349Z"}
# {"customer_id": "a255b789-4fdb-4af0-a88b-996b97b86521", "tenant_id": "79f522b8-dd35-4685-bf37-6aa9f387f314", "field_count": 0, "event": "customer_data_loaded", "level": "info", "timestamp": "[PHONE]T02:00:26.206147Z"}
# {"tenant_id": "79f522b8-dd35-4685-bf37-6aa9f387f314", "agent_id": "53bf3f[PHONE]e-b38f-2316c4557686", "item_count": 0, "event": "glossary_loaded", "level": "info", "timestamp": "[PHONE]T02:00:26.206650Z"}
# {"tenant_id": "79f522b8-dd35-4685-bf37-6aa9f387f314", "agent_id": "53bf3f[PHONE]e-b38f-2316c4557686", "field_count": 0, "event": "customer_data_schema_loaded", "level": "info", "timestamp": "[PHONE]T02:00:26.207162Z"}
# {"model": "openrouter/openai/gpt-oss-120b", "step": "situational_sensor", "latency_ms": 1628.58, "content_length": 496, "backend_provider": "OpenRouter", "event": "executor_generate_complete", "level": "debug", "timestamp": "[PHONE]T02:00:27.836402Z"}
# {"model": "jina-embeddings-v3", "task": "retrieval.passage", "dimensions": 1024, "num_texts": 1, "event": "jina_embed_request", "level": "debug", "timestamp": "[PHONE]T02:00:27.837276Z"}
# {"model": "jina-embeddings-v3", "task": "retrieval.passage", "dimensions": 1024, "num_texts": 1, "event": "jina_embed_request", "level": "debug", "timestamp": "[PHONE]T02:00:27.839818Z"}
# {"tenant_id": "79f522b8-dd35-4685-bf37-6aa9f387f314", "agent_id": "53bf3f[PHONE]e-b38f-2316c4557686", "event": "no_intents_configured", "level": "debug", "timestamp": "[PHONE]T02:00:27.843357Z"}
# {"model": "jina-embeddings-v3", "num_embeddings": 1, "dimensions": 1024, "event": "jina_embed_success", "level": "debug", "timestamp": "[PHONE]T02:00:28.302660Z"}
# {"model": "jina-embeddings-v3", "num_embeddings": 1, "dimensions": 1024, "event": "jina_embed_success", "level": "debug", "timestamp": "[PHONE]T02:00:28.480088Z"}
# {"total_candidates": 4, "selected": 1, "elapsed_ms": 644.4987650029361, "event": "rules_retrieved", "level": "debug", "timestamp": "[PHONE]T02:00:28.481801Z"}
# {"intent": "refund_request", "confidence": 0.0, "hybrid_candidates_count": 0, "reason": "no_confident_match", "event": "using_sensor_intent_fallback", "level": "debug", "timestamp": "[PHONE]T02:00:28.483606Z"}
# {"count": 1, "elapsed_ms": 647.646629717201, "event": "rules_retrieved", "level": "debug", "timestamp": "[PHONE]T02:00:28.484916Z"}
# {"num_candidates": 1, "batch_size": 5, "event": "filtering_rules", "level": "debug", "timestamp": "[PHONE]T02:00:28.485915Z"}
# {"model": "openrouter/openai/gpt-oss-120b", "step": "rule_filtering", "latency_ms": 1293.37, "content_length": 496, "backend_provider": "OpenRouter", "event": "executor_generate_complete", "level": "debug", "timestamp": "[PHONE]T02:00:29.781925Z"}
# {"matched": 0, "rejected": 1, "unsure": 0, "unsure_policy": "exclude", "elapsed_ms": 1296.873405110091, "event": "rules_filtered", "level": "info", "timestamp": "[PHONE]T02:00:29.782803Z"}
# {"response_type": "ANSWER", "num_rules": 0, "num_contributions": 0, "event": "response_type_determined", "level": "info", "timestamp": "[PHONE]T02:00:29.783583Z"}
# {"response_type": "ANSWER", "num_templates": 0, "num_contributions": 0, "num_must_include": 0, "num_must_avoid": 0, "num_constraints": 0, "event": "response_plan_built", "level": "info", "timestamp": "[PHONE]T02:00:29.785750Z"}
# {"model": "openrouter/openai/gpt-oss-120b", "step": "generation", "latency_ms": 1519.54, "content_length": 382, "backend_provider": "OpenRouter", "event": "executor_generate_complete", "level": "debug", "timestamp": "[PHONE]T02:00:31.307890Z"}
# {"error": "Expecting value: line 1 column 1 (char 0)", "event": "llm_output_not_json", "level": "debug", "timestamp": "[PHONE]T02:00:31.309142Z"}
# {"response_length": 382, "elapsed_ms": 1521.7467029578984, "model": "openrouter/openai/gpt-oss-120b", "response_type": "ANSWER", "categories": 1, "channel": "web", "event": "response_generated", "level": "debug", "timestamp": "[PHONE]T02:00:31.309827Z"}
# {"session_id": "0be0b7af-d362-4b5e-97f4-98d5e1e19dee", "operations": 1, "duration_ms": 0.2604769542813301, "failures": 0, "event": "parallel_persistence_complete", "level": "info", "timestamp": "[PHONE]T02:00:31.310856Z"}
# {"session_id": "0be0b7af-d362-4b5e-97f4-98d5e1e19dee", "turn_id": "9a57b888-834b-403d-81d5-a365cec2dff7", "total_time_ms": 5108.697933144867, "matched_rules": 0, "response_length": 382, "event": "turn_processed", "level": "info", "timestamp": "[PHONE]T02:00:31.311512Z"}
# ======================================================================
# MESSAGE: I want a refund. The product arrived damaged.
# ======================================================================
#
# RESPONSE:
# I’m sorry to hear that the product arrived damaged. Let’s get this sorted quickly.
#
# 1. Could you please provide your order number (or the email you used for the purchase)?
# 2. If possible, send a photo of the damage—this helps us process the refund faster.
#
# Once I have that information, I’ll initiate the refund and arrange for a return label if needed. Thank you for your patience.
#
# ======================================================================
# PIPELINE LATENCIES:
# ======================================================================
#   customer_resolution       0.55ms
#   reconciliation            SKIPPED
#   situational_sensor        1631.07ms
#   retrieval                 647.65ms
#   rule_filtering            1297.46ms
#   scenario_filtering        0.03ms
#   requirement_check         SKIPPED
#   tool_execution            SKIPPED
#   response_planning         4.43ms
#   generation                1522.40ms
#   enforcement               SKIPPED
#   ────────────────────────────────────────
#   TOTAL                     5108.70ms
#
# Matched Rules: 0
#
# Situational Snapshot:
#   Language: en
#   Sentiment: Sentiment.FRUSTRATED
#   Topic: refund

# %% [markdown]
# ## Try Your Own

# %%
# Try your own message
message = "Can you help me track order #12345?"

result = run(engine.process_turn(
    message=message,
    session_id=ctx.session_id,
    tenant_id=ctx.tenant_id,
    agent_id=ctx.agent_id,
))

display_result(result, message)
# Out:
# {"session_id": "0be0b7af-d362-4b5e-97f4-98d5e1e19dee", "tenant_id": "79f522b8-dd35-4685-bf37-6aa9f387f314", "agent_id": "53bf3f[PHONE]e-b38f-2316c4557686", "message_length": 35, "event": "processing_turn", "level": "info", "timestamp": "[PHONE]T05:14:24.649005Z"}
# {"tenant_id": "79f522b8-dd35-4685-bf37-6aa9f387f314", "customer_id": "a255b789-4fdb-4af0-a88b-996b97b86521", "channel": "api", "event": "customer_resolved", "level": "info", "timestamp": "[PHONE]T05:14:24.689385Z"}
# {"tenant_id": "79f522b8-dd35-4685-bf37-6aa9f387f314", "agent_id": "53bf3f[PHONE]e-b38f-2316c4557686", "item_count": 0, "event": "glossary_loaded", "level": "info", "timestamp": "[PHONE]T05:14:24.712126Z"}
# {"tenant_id": "79f522b8-dd35-4685-bf37-6aa9f387f314", "agent_id": "53bf3f[PHONE]e-b38f-2316c4557686", "field_count": 0, "event": "customer_data_schema_loaded", "level": "info", "timestamp": "[PHONE]T05:14:24.714492Z"}
# {"customer_id": "a255b789-4fdb-4af0-a88b-996b97b86521", "tenant_id": "79f522b8-dd35-4685-bf37-6aa9f387f314", "field_count": 0, "event": "customer_data_loaded", "level": "info", "timestamp": "[PHONE]T05:14:24.722555Z"}
# {"tenant_id": "79f522b8-dd35-4685-bf37-6aa9f387f314", "agent_id": "53bf3f[PHONE]e-b38f-2316c4557686", "session_id": "0be0b7af-d362-4b5e-97f4-98d5e1e19dee", "customer_id": "a255b789-4fdb-4af0-a88b-996b97b86521", "turn_number": 5, "is_new_customer": false, "has_reconciliation": false, "event": "turn_context_built", "level": "info", "timestamp": "[PHONE]T05:14:24.781359Z"}
# {"customer_id": "a255b789-4fdb-4af0-a88b-996b97b86521", "tenant_id": "79f522b8-dd35-4685-bf37-6aa9f387f314", "field_count": 0, "event": "customer_data_loaded", "level": "info", "timestamp": "[PHONE]T05:14:24.790033Z"}
# {"tenant_id": "79f522b8-dd35-4685-bf37-6aa9f387f314", "agent_id": "53bf3f[PHONE]e-b38f-2316c4557686", "item_count": 0, "event": "glossary_loaded", "level": "info", "timestamp": "[PHONE]T05:14:24.791443Z"}
# {"tenant_id": "79f522b8-dd35-4685-bf37-6aa9f387f314", "agent_id": "53bf3f[PHONE]e-b38f-2316c4557686", "field_count": 0, "event": "customer_data_schema_loaded", "level": "info", "timestamp": "[PHONE]T05:14:24.794909Z"}
# {"error": "'situational_sensor.jinja2' not found in search path: '/home/marvin/Projects/soldier/soldier/alignment/context/prompts'", "tenant_id": "79f522b8-dd35-4685-bf37-6aa9f387f314", "agent_id": "53bf3f[PHONE]e-b38f-2316c4557686", "event": "situational_sensor_failed", "level": "warning", "timestamp": "[PHONE]T05:14:24.817063Z"}
# {"model": "jina-embeddings-v3", "task": "retrieval.passage", "dimensions": 1024, "num_texts": 1, "event": "jina_embed_request", "level": "debug", "timestamp": "[PHONE]T05:14:24.835387Z"}
# {"model": "jina-embeddings-v3", "task": "retrieval.passage", "dimensions": 1024, "num_texts": 1, "event": "jina_embed_request", "level": "debug", "timestamp": "[PHONE]T05:14:24.926305Z"}
# {"tenant_id": "79f522b8-dd35-4685-bf37-6aa9f387f314", "agent_id": "53bf3f[PHONE]e-b38f-2316c4557686", "event": "no_intents_configured", "level": "debug", "timestamp": "[PHONE]T05:14:24.936827Z"}
# {"model": "jina-embeddings-v3", "num_embeddings": 1, "dimensions": 1024, "event": "jina_embed_success", "level": "debug", "timestamp": "[PHONE]T05:14:26.633188Z"}
# {"model": "jina-embeddings-v3", "num_embeddings": 1, "dimensions": 1024, "event": "jina_embed_success", "level": "debug", "timestamp": "[PHONE]T05:14:26.650733Z"}
# {"total_candidates": 4, "selected": 1, "elapsed_ms": 1855.1056100986898, "event": "rules_retrieved", "level": "debug", "timestamp": "[PHONE]T05:14:26.683179Z"}
# {"intent": null, "confidence": 0.0, "hybrid_candidates_count": 0, "reason": "no_confident_match", "event": "using_sensor_intent_fallback", "level": "debug", "timestamp": "[PHONE]T05:14:26.686823Z"}
# {"count": 1, "elapsed_ms": 1865.3141898103058, "event": "rules_retrieved", "level": "debug", "timestamp": "[PHONE]T05:14:26.689031Z"}
# {"num_candidates": 1, "batch_size": 5, "event": "filtering_rules", "level": "debug", "timestamp": "[PHONE]T05:14:26.691680Z"}
# {"model": "openrouter/openai/gpt-oss-120b", "step": "rule_filtering", "latency_ms": 3542.27, "content_length": 357, "backend_provider": "OpenRouter", "event": "executor_generate_complete", "level": "debug", "timestamp": "[PHONE]T05:14:30.253740Z"}
# {"matched": 0, "rejected": 1, "unsure": 0, "unsure_policy": "exclude", "elapsed_ms": 3567.763052880764, "event": "rules_filtered", "level": "info", "timestamp": "[PHONE]T05:14:30.259255Z"}
# {"response_type": "ANSWER", "num_rules": 0, "num_contributions": 0, "event": "response_type_determined", "level": "info", "timestamp": "[PHONE]T05:14:30.277513Z"}
# {"response_type": "ANSWER", "num_templates": 0, "num_contributions": 0, "num_must_include": 0, "num_must_avoid": 0, "num_constraints": 0, "event": "response_plan_built", "level": "info", "timestamp": "[PHONE]T05:14:30.280874Z"}
# {"model": "openrouter/openai/gpt-oss-120b", "step": "generation", "latency_ms": 1769.01, "content_length": 290, "backend_provider": "OpenRouter", "event": "executor_generate_complete", "level": "debug", "timestamp": "[PHONE]T05:14:32.055830Z"}
# {"error": "Expecting value: line 1 column 1 (char 0)", "event": "llm_output_not_json", "level": "debug", "timestamp": "[PHONE]T05:14:32.058336Z"}
# {"response_length": 290, "elapsed_ms": 1776.0211606509984, "model": "openrouter/openai/gpt-oss-120b", "response_type": "ANSWER", "categories": 1, "channel": "web", "event": "response_generated", "level": "debug", "timestamp": "[PHONE]T05:14:32.059902Z"}
# {"session_id": "0be0b7af-d362-4b5e-97f4-98d5e1e19dee", "operations": 1, "duration_ms": 3.271467052400112, "failures": 0, "event": "parallel_persistence_complete", "level": "info", "timestamp": "[PHONE]T05:14:32.070374Z"}
# {"session_id": "0be0b7af-d362-4b5e-97f4-98d5e1e19dee", "turn_id": "946fe27d-3a80-49c1-b[PHONE]c84a66", "total_time_ms": 7444.234906695783, "matched_rules": 0, "response_length": 290, "event": "turn_processed", "level": "info", "timestamp": "[PHONE]T05:14:32.071703Z"}
# ======================================================================
# MESSAGE: Can you help me track order #12345?
# ======================================================================
#
# RESPONSE:
# I’d be happy to help you check on that order. Could you please confirm a few details for me?
#
# 1. The email address or phone number associated with the order.
# 2. Any shipping or billing name you used.
#
# Once I have that information, I can look up the current status of order #12345 for you.
#
# ======================================================================
# PIPELINE LATENCIES:
# ======================================================================
#   customer_resolution       8.79ms
#   reconciliation            SKIPPED
#   situational_sensor        SKIPPED
#   retrieval                 1865.31ms
#   rule_filtering            3570.35ms
#   scenario_filtering        1.96ms
#   requirement_check         SKIPPED
#   tool_execution            SKIPPED
#   response_planning         16.59ms
#   generation                1778.69ms
#   enforcement               SKIPPED
#   ────────────────────────────────────────
#   TOTAL                     7444.23ms
#
# Matched Rules: 0

# %% [markdown]
# ## Notes
#
# **Expected Latencies (with Cerebras/Groq routing):**
#
# | Step | Time | Notes |
# |------|------|-------|
# | customer_resolution | <1ms | In-memory lookup |
# | situational_sensor | 2-5s | LLM extracts context |
# | retrieval | 500ms | Jina embedding + search |
# | rule_filtering | 1-3s | LLM judges rules |
# | generation | 1-3s | LLM generates response |
#
# **Without provider routing** = 20-30s per LLM call
# **With provider routing** = 1-5s per LLM call
